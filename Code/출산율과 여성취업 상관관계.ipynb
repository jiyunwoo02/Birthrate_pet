# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel('c:/new/first.xlsx')
df
# Out:
#    year  employ  birth
# 0  2019    51.6  0.918
# 1  2020    50.7  0.837
# 2  2021    51.2  0.808

# %%
df.corr()
# Out:
#             year    employ     birth
# year    1.000000 -0.443533 -0.964714
# employ -0.443533  1.000000  0.663866
# birth  -0.964714  0.663866  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
