# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel('c:/new/second.xlsx')
df
# Out:
#     year place  elementary  animal clinic
# 0   2019    서울         607             19
# 1   2019    부산         304             14
# 2   2019    대구         229             11
# 3   2019    인천         250              4
# 4   2019    광주         155              3
# 5   2019    대전         148              6
# 6   2019    울산         119              5
# 7   2019    세종          48              0
# 8   2019    경기        1277             14
# 9   2019    강원         349             20
# 10  2019    충북         259              7
# 11  2019    충남         409             16
# 12  2019    전북         419             19
# 13  2019    전남         429             17
# 14  2019    경북         471             26
# 15  2019    경남         501             21
# 16  2019    제주         113              4
# 17  2020    서울         607             19
# 18  2020    부산         304             14
# 19  2020    대구         230             11
# 20  2020    인천         253              4
# ...

# %%
df.corr()
# Out:
#                    year  elementary  animal clinic
# year           1.000000    0.006014       0.006467
# elementary     0.006014    1.000000       0.553508
# animal clinic  0.006467    0.553508       1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
