# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

# %%
import pandas as pd
df = pd.read_excel('babyborn.xls', skiprows=2, nrows=2, index_col=0)
df
# Out:
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019    2020    2021
# 출생아 수   302.700  272.30  260.60
# 합계 출산율    0.918    0.84    0.81

# %%
df.index.values
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
df.rename(index={'출생아\xa0수':'출생아 수','합계\xa0출산율':'합계 출산율'},inplace=True)
df
# Out:
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019    2020    2021
# 출생아 수   302.700  272.30  260.60
# 합계 출산율    0.918    0.84    0.81

# %%
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
df.loc['출생아 수']
# Out:
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# 2021    260.6
# Name: 출생아 수, dtype: float64

# %%
df=df.T
df
# Out:
#       출생아 수  합계 출산율
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.840
# 2021  260.6   0.810

# %%
import matplotlib.pyplot as plt
plt.plot(df.index,df['출생아 수'])
plt.plot(df.index,df['합계 출산율'])

# %%
fig,ax1=plt.subplots(figsize=(10,5))
ax1.plot(df.index,df['출생아 수'],color='red',marker='o')

ax2=ax1.twinx()
ax2.plot(df.index,df['합계 출산율'],color='blue',marker='o')

# %%
fig,ax1=plt.subplots(figsize=(12,5))
ax1.bar(df.index,df['출생아 수'],color='#7FB0EF', label='단위: 천명')
ax1.set_ylim(200,700)
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val+12, val, ha='center')

ax2=ax1.twinx()
ax2.plot(df.index,df['합계 출산율'],color='#9A48E2',marker='o',ms=10,lw=3, label='단위: 1명당 명')
ax2.set_ylim(0,1.5)
for idx, val in enumerate(df['합계 출산율']):
    ax2.text(idx, val+0.08, val, ha='center')

ax2.legend(loc='upper right')    
plt.title('출생아 수 & 합계 출산율')
# Out:
# Text(0.5, 1.0, '출생아 수 & 합계 출산율')
